# %%
import numpy as np

def daoham(x):
    return 2*x + 2

def hamfx(x):
    return x*x + 2*x + 5

x = -20
numof = 1000
cost = np.zeros((numof,1))
learning_rate = 0.01
for i in range(1, numof):
    #tính giá trị dự đoán
    cost[i] = hamfx(x)
    print (x, cost[i])
    
    #gradient descent
    x -= learning_rate * daoham(x)
# Out:
# -20 [365.]
# -19.62 [350.7044]
# -19.247600000000002 [336.97490576]
# -18.882648000000003 [323.78909949]
# -18.524995040000004 [311.12545115]
# -18.174495139200005 [298.96328329]
# -17.831005236416004 [287.28273727]
# -17.494385131687686 [276.06474087]
# -17.16449742905393 [265.29097713]
# -16.841207480472853 [254.94385444]
# -16.524383330863397 [245.0064778]
# -16.21389566424613 [235.46262128]
# -15.909617750961209 [226.29670148]
# -15.611425395941984 [217.4937521]
# -15.319196888023145 [209.03939952]
# -15.03281295026268 [200.9198393]
# -14.752156691257428 [193.12181366]
# -14.47711355743228 [185.63258984]
# -14.207571286283633 [178.43993928]
# -13.94341986055796 [171.53211769]
# -13.6845514633468 [164.89784583]
# -13.430860434079865 [158.52629113]
# -13.182243225398267 [152.40705]
# -12.938598360890301 [146.53013082]
# -12.699826393672495 [140.88593764]
# -12.465829865799046 [135.46525451]
# -12.236513268483066 [130.25923043]
# -12.011783003113404 [125.25936491]
# ...
